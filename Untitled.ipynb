# %%
import rpy2

# %%
rpy2.__version__
# Out:
# '2.9.5'

# %%
dir(rpy2)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '__version_vector__']

# %%
import rpy2.robjects as robjects

# %%
from rpy2.robjects.packages import importr
# import R's "base" package
base = importr('base')

# %%
dir(base)
# Out:
# ['!',
#  '!=',
#  '!_hexmode',
#  '!_octmode',
#  '$',
#  '$<-',
#  '$<-_data_frame',
#  '$_DLLInfo',
#  '$_data_frame',
#  '$_package_version',
#  '%%',
#  '%*%',
#  '%/%',
#  '%in%',
#  '%o%',
#  '%x%',
#  '&',
#  '&&',
#  '&_hexmode',
#  '&_octmode',
#  '(',
#  '*',
#  '*_difftime',
#  '+',
#  '+_Date',
#  '+_POSIXt',
#  '-',
#  '-_Date',
#  '-_POSIXt',
#  '/',
#  '/_difftime',
#  ':',
#  '::',
#  ':::',
#  '<',
#  '<-',
#  '<<-',
#  '<=',
#  '=',
#  '==',
#  '>',
#  '>=',
#  '@',
#  '@<-',
#  'Arg',
#  'Conj',
#  'Cstack_info',
#  'Encoding',
#  'Encoding<-',
#  'F',
#  'Filter',
#  'Find',
#  'I',
#  'ISOdate',
#  'ISOdatetime',
#  'Im',
#  'LETTERS',
#  'La_library',
#  'La_svd',
#  'La_version',
#  'Map',
#  'Math_Date',
#  'Math_POSIXt',
#  'Math_data_frame',
#  'Math_difftime',
#  'Math_factor',
#  'Mod',
#  'NCOL',
#  'NROW',
#  'Negate',
#  'NextMethod',
#  'OlsonNames',
#  'Ops_Date',
#  'Ops_POSIXt',
#  'Ops_data_frame',
#  'Ops_difftime',
#  'Ops_factor',
# ...
